# %% [markdown]
# ***Actividad 2.2***

# %% [markdown]
# Bernardo Quintana López A01658064

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Londres_Inglaterra.csv")
df
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                56229   2024-12-12  city scrape     216660
# 1               1                62970   2024-12-12  city scrape     336059
# 2               2                63948   2024-12-12  city scrape     216660
# 3               3                66772   2024-12-11  city scrape     216660
# 4               4                69198   2024-12-11  city scrape     345886
# ...           ...                  ...          ...          ...        ...
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
# 95140       95140  1307790077052699904   2024-12-11  city scrape   50878819
# 95141       95141  1307791573107140096   2024-12-12  city scrape  131418248
# 95142       95142  1307794952877420032   2024-12-11  city scrape  252350161
# 95143       95143  1307795865634990080   2024-12-11  city scrape   71174892
#
# ...

# %% [markdown]
# ***Ejercicio A***

# %%
filtroa = df[(df["review_scores_communication"] >= 3) & (df["host_is_superhost"] == "f")]
filtroa.to_csv("CalifComunicación&Superhost.csv")
filtroa
# Out:
#        Unnamed: 0                   id last_scraped           source  \
# 0               0                56229   2024-12-12      city scrape
# 2               2                63948   2024-12-12      city scrape
# 3               3                66772   2024-12-11      city scrape
# 4               4                69198   2024-12-11      city scrape
# 5               5                72913   2024-12-12  previous scrape
# ...           ...                  ...          ...              ...
# 94669       94669  1305601896618220032   2024-12-11      city scrape
# 94670       94670  1305607883704160000   2024-12-12      city scrape
# 94785       94785  1305031476353920000   2024-12-12      city scrape
# 94799       94799  1305919184419869952   2024-12-12      city scrape
# 94985       94985  1307296285250109952   2024-12-11      city scrape
#
#          host_id       host_name host_since                 host_location  \
# ...

# %% [markdown]
# ***Ejercicio B***

# %%
filtrob = df[df["bathrooms"] != 1]
filtrob.to_csv("NoTienen1Baño.csv")
filtrob
# Out:
#        Unnamed: 0                   id last_scraped           source  \
# 0               0                56229   2024-12-12      city scrape
# 1               1                62970   2024-12-12      city scrape
# 5               5                72913   2024-12-12  previous scrape
# 6               6                73431   2024-12-11      city scrape
# 7               7                78606   2024-12-12  previous scrape
# ...           ...                  ...          ...              ...
# 95119       95119  1307455988011660032   2024-12-11      city scrape
# 95132       95132  1308833968163249920   2024-12-12      city scrape
# 95133       95133  1307551777575889920   2024-12-12      city scrape
# 95139       95139  1307783883910080000   2024-12-12      city scrape
# 95141       95141  1307791573107140096   2024-12-12      city scrape
#
#          host_id   host_name host_since             host_location  \
# 0         216660       Boris 2010-08-29    London, United Kingdom
# ...

# %% [markdown]
# ***Ejercicio C***

# %%
filtroc = df[(df["price"] >= 100) & (df["price"] <= 200)]
filtroc.to_csv("PrecioEntre100&200.csv")
filtroc
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 6               6                73431   2024-12-11  city scrape     383525
# 10             10               347389   2024-12-11  city scrape    1090342
# 20             20                15400   2024-12-11  city scrape      60302
# 23             23                31036   2024-12-12  city scrape     133271
# 24             24                33332   2024-12-11  city scrape     144444
# ...           ...                  ...          ...          ...        ...
# 95130       95130  1307489085325740032   2024-12-12  city scrape  418475703
# 95134       95134  1307734047852349952   2024-12-11  city scrape  666114640
# 95136       95136  1307757038796689920   2024-12-12  city scrape   30686988
# 95137       95137  1307765989557890048   2024-12-12  city scrape  299222427
# 95143       95143  1307795865634990080   2024-12-11  city scrape   71174892
#
#          host_name host_since  \
# ...

# %% [markdown]
# ***Ejercicio D***

# %%
filtrod = df[(df["instant_bookable"] == "t") & (df["host_identity_verified"] == "t")]
filtrod.to_csv("IdentidadHost&ReservacionInmediata.csv")
filtrod
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 1               1                62970   2024-12-12  city scrape     336059
# 6               6                73431   2024-12-11  city scrape     383525
# 23             23                31036   2024-12-12  city scrape     133271
# 26             26                36660   2024-12-11  city scrape     157884
# 37             37                42010   2024-12-11  city scrape     157884
# ...           ...                  ...          ...          ...        ...
# 95131       95131  1308742431251650048   2024-12-12  city scrape    1432477
# 95132       95132  1308833968163249920   2024-12-12  city scrape   27572615
# 95133       95133  1307551777575889920   2024-12-12  city scrape  339340565
# 95137       95137  1307765989557890048   2024-12-12  city scrape  299222427
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
#
# ...

# %% [markdown]
# ***Ejercicio E***

# %%
filtroe = df[df["room_type"].isin(["Hotel room", "Private room"])]
filtroe.to_csv("TiposdeCuartos.csv")
filtroe
# Out:
#        Unnamed: 0                   id last_scraped           source  \
# 3               3                66772   2024-12-11      city scrape
# 4               4                69198   2024-12-11      city scrape
# 5               5                72913   2024-12-12  previous scrape
# 7               7                78606   2024-12-12  previous scrape
# 8               8                78892   2024-12-11      city scrape
# ...           ...                  ...          ...              ...
# 95120       95120  1307458353842619904   2024-12-11      city scrape
# 95128       95128  1307460498859840000   2024-12-11      city scrape
# 95129       95129  1307462714672770048   2024-12-11      city scrape
# 95141       95141  1307791573107140096   2024-12-12      city scrape
# 95142       95142  1307794952877420032   2024-12-11      city scrape
#
#          host_id host_name host_since            host_location  \
# 3         216660     Boris 2010-08-29   London, United Kingdom
# ...

# %% [markdown]
# ***Ejercicio F***

# %%
filtrof = df[df["accommodates"] > 4]
filtrof.to_csv("AccommodatesMayora4.csv")
filtrof
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 1               1                62970   2024-12-12  city scrape     336059
# 6               6                73431   2024-12-11  city scrape     383525
# 13             13               348217   2024-12-12  city scrape    1621004
# 21             21                17402   2024-12-12  city scrape      67564
# 25             25                36299   2024-12-11  city scrape     155938
# ...           ...                  ...          ...          ...        ...
# 95094       95094  1308218208665440000   2024-12-12  city scrape   69184739
# 95102       95102  1308547155938370048   2024-12-11  city scrape  325614755
# 95108       95108  1308053760266170112   2024-12-11  city scrape  139997717
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
# 95141       95141  1307791573107140096   2024-12-12  city scrape  131418248
#
# ...
