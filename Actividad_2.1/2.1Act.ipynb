# %% [markdown]
# ***ACTIVIDAD 2.1***

# %% [markdown]
# *Bernardo Quintana López*

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
#Carga de archivo
df = pd.read_csv("Londres_Inglaterra.csv")
df
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                56229   2024-12-12  city scrape     216660
# 1               1                62970   2024-12-12  city scrape     336059
# 2               2                63948   2024-12-12  city scrape     216660
# 3               3                66772   2024-12-11  city scrape     216660
# 4               4                69198   2024-12-11  city scrape     345886
# ...           ...                  ...          ...          ...        ...
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
# 95140       95140  1307790077052699904   2024-12-11  city scrape   50878819
# 95141       95141  1307791573107140096   2024-12-12  city scrape  131418248
# 95142       95142  1307794952877420032   2024-12-11  city scrape  252350161
# 95143       95143  1307795865634990080   2024-12-11  city scrape   71174892
#
# ...

# %% [markdown]
# ***Ejercicio A***

# %%
#Registros de 5 hosts con nombres diferentes 
filtroa = df.drop_duplicates(subset=['host_name']).iloc[:5]
filtroa.to_csv('HostsDiferentes.csv')
filtroa
# Out:
#    Unnamed: 0     id last_scraped           source  host_id host_name  \
# 0           0  56229   2024-12-12      city scrape   216660     Boris
# 1           1  62970   2024-12-12      city scrape   336059    Thomas
# 4           4  69198   2024-12-11      city scrape   345886      Alda
# 5           5  72913   2024-12-12  previous scrape   379315   Matthew
# 6           6  73431   2024-12-11      city scrape   383525       Emi
#
#   host_since             host_location host_is_superhost host_neighbourhood  \
# 0 2010-08-29    London, United Kingdom                 f        Hammersmith
# 1 2011-01-05  Hamilton Parish, Bermuda               NaN          Mid-Beach
# 4 2011-01-13    London, United Kingdom                 f                NaN
# 5 2011-02-06            United Kingdom                 f         Kennington
# 6 2011-02-09    London, United Kingdom                 f          Stockwell
#
#    ...  review_scores_cleanliness review_scores_checkin  \
# ...

# %% [markdown]
# ***Ejercicio B***

# %%
#Registros de hosts que hayan unido a Airbnb después del año 2020
filtrob=df[df["host_since"] > "31/12/20"]
filtrob.to_csv("HostsDespués2020.csv")
filtrob
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 1407         1407              1334961   2024-12-12  city scrape  463078446
# 2710         2710              4314594   2024-12-11  city scrape  409088462
# 3291         3291              5168987   2024-12-12  city scrape  650574345
# 3346         3346              5198507   2024-12-12  city scrape  650574345
# 3713         3713              5132321   2024-12-12  city scrape  650574345
# ...           ...                  ...          ...          ...        ...
# 95129       95129  1307462714672770048   2024-12-11  city scrape  551176448
# 95130       95130  1307489085325740032   2024-12-12  city scrape  418475703
# 95134       95134  1307734047852349952   2024-12-11  city scrape  666114640
# 95138       95138  1307782428690180096   2024-12-12  city scrape  529189406
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
#
# ...

# %% [markdown]
# ***Ejercicio C***

# %%
#Registros de hosts que tengan al menos calificación de 3 en comunicación
filtroc = df[df["review_scores_communication"] >= 3]
filtroc.to_csv("HostCalif3omas.csv")
filtroc
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                56229   2024-12-12  city scrape     216660
# 1               1                62970   2024-12-12  city scrape     336059
# 2               2                63948   2024-12-12  city scrape     216660
# 3               3                66772   2024-12-11  city scrape     216660
# 4               4                69198   2024-12-11  city scrape     345886
# ...           ...                  ...          ...          ...        ...
# 94785       94785  1305031476353920000   2024-12-12  city scrape  664383752
# 94799       94799  1305919184419869952   2024-12-12  city scrape  472181600
# 94850       94850  1306570599143859968   2024-12-12  city scrape  555348745
# 94985       94985  1307296285250109952   2024-12-11  city scrape   49771601
# 95065       95065  1307374861435460096   2024-12-12  city scrape  441920235
#
# ...

# %% [markdown]
# ***Ejercicio D***

# %%
#Registros de filas múltiplos de 200
filtrod = df.iloc[::200]
filtrod.to_csv("FilasMultiplos200.csv")
filtrod
# Out:
#        Unnamed: 0                   id last_scraped           source  \
# 0               0                56229   2024-12-12      city scrape
# 200           200               392858   2024-12-11      city scrape
# 400           400               238440   2024-12-12  previous scrape
# 600           600               581237   2024-12-12  previous scrape
# 800           800               656590   2024-12-11      city scrape
# ...           ...                  ...          ...              ...
# 94200       94200  1303437221310729984   2024-12-12      city scrape
# 94400       94400  1303669825290909952   2024-12-12      city scrape
# 94600       94600  1304370621159660032   2024-12-12      city scrape
# 94800       94800  1305919415890099968   2024-12-12      city scrape
# 95000       95000  1307956626131219968   2024-12-12      city scrape
#
#          host_id       host_name host_since            host_location  \
# ...

# %% [markdown]
# ***Ejercicio E***

# %%
#Registros con tipos de cuarto: "Entire home/apt" y "Private room"
filtroe=df[df["room_type"].isin(["Entire home/apt", "Private room"])]
filtroe.to_csv("TipodeCuarto.csv")
filtroe
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                56229   2024-12-12  city scrape     216660
# 1               1                62970   2024-12-12  city scrape     336059
# 2               2                63948   2024-12-12  city scrape     216660
# 3               3                66772   2024-12-11  city scrape     216660
# 4               4                69198   2024-12-11  city scrape     345886
# ...           ...                  ...          ...          ...        ...
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
# 95140       95140  1307790077052699904   2024-12-11  city scrape   50878819
# 95141       95141  1307791573107140096   2024-12-12  city scrape  131418248
# 95142       95142  1307794952877420032   2024-12-11  city scrape  252350161
# 95143       95143  1307795865634990080   2024-12-11  city scrape   71174892
#
# ...

# %% [markdown]
# ***Ejercicio F***

# %%
#Registros que a lo mucho tengan 4 camas
filtrof=df[df["beds"] <= 4]
filtrof.to_csv("4camasomenos.csv")
filtrof
# Out:
#        Unnamed: 0                   id last_scraped       source    host_id  \
# 0               0                56229   2024-12-12  city scrape     216660
# 1               1                62970   2024-12-12  city scrape     336059
# 2               2                63948   2024-12-12  city scrape     216660
# 3               3                66772   2024-12-11  city scrape     216660
# 4               4                69198   2024-12-11  city scrape     345886
# ...           ...                  ...          ...          ...        ...
# 95139       95139  1307783883910080000   2024-12-12  city scrape  445228166
# 95140       95140  1307790077052699904   2024-12-11  city scrape   50878819
# 95141       95141  1307791573107140096   2024-12-12  city scrape  131418248
# 95142       95142  1307794952877420032   2024-12-11  city scrape  252350161
# 95143       95143  1307795865634990080   2024-12-11  city scrape   71174892
#
# ...

# %% [markdown]
# ***Ejercicio G***

# %%
#Registros que sean superhost
filtrog=df[df["host_is_superhost"] == "t"]
filtrog.to_csv("HostesSuperhost.csv")
filtrog
# Out:
#        Unnamed: 0                   id last_scraped           source  \
# 9               9               346523   2024-12-12  previous scrape
# 12             12               348215   2024-12-12      city scrape
# 13             13               348217   2024-12-12      city scrape
# 17             17               350588   2024-12-12  previous scrape
# 18             18               351727   2024-12-11      city scrape
# ...           ...                  ...          ...              ...
# 95053       95053  1308137199957410048   2024-12-12      city scrape
# 95065       95065  1307374861435460096   2024-12-12      city scrape
# 95095       95095  1308224624750190080   2024-12-12      city scrape
# 95097       95097  1308231066978690048   2024-12-12      city scrape
# 95132       95132  1308833968163249920   2024-12-12      city scrape
#
#          host_id  host_name host_since                host_location  \
# 9        1756532      Julia 2012-02-15       London, United Kingdom
# ...

# %% [markdown]
# ***Ejercicio H***

# %%
#Registros de columnas impares
filtroh = df.iloc[:, 1::2]
filtroh.to_csv("ColumnasImpares.csv")
filtroh
# Out:
#                         id       source   host_name             host_location  \
# 0                    56229  city scrape       Boris    London, United Kingdom
# 1                    62970  city scrape      Thomas  Hamilton Parish, Bermuda
# 2                    63948  city scrape       Boris    London, United Kingdom
# 3                    66772  city scrape       Boris    London, United Kingdom
# 4                    69198  city scrape        Alda    London, United Kingdom
# ...                    ...          ...         ...                       ...
# 95139  1307783883910080000  city scrape  Anastasiia                       NaN
# 95140  1307790077052699904  city scrape       Susan    London, United Kingdom
# 95141  1307791573107140096  city scrape       Steve    London, United Kingdom
# 95142  1307794952877420032  city scrape      Ursula   England, United Kingdom
# 95143  1307795865634990080  city scrape      Chione    London, United Kingdom
#
# ...
